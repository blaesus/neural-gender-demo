# %%
from glob import glob
from scipy.misc import imread
import numpy as np
import os
# load training data

images = []
genders = []

image_paths = glob('./data/girl/*')

for path in image_paths:
    data = imread(path, flatten=True).flatten()
    images.append(data)
    genders.append((1, 0))

image_paths = glob('./data/nongirl/*')

for path in image_paths:
    data = imread(path, flatten=True).flatten()
    images.append(data)
    genders.append((0, 1))

images = np.asarray(images)
genders = np.asarray(genders)
    
print(images.shape)
print(genders.shape)
# Out:
# (71, 1024)
# (71, 2)

# %%
# Train model

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD

model = Sequential([
        Dense(100, input_dim=images[0].size, activation='relu'),   
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(2, activation='softmax'),
    ])

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(images, genders, nb_epoch=50)
# Out:
# Epoch 1/50
# 71/71 [==============================] - 1s - loss: 1.5443 - acc: 0.4366
# Epoch 2/50
# 71/71 [==============================] - 0s - loss: 0.8739 - acc: 0.5493
# Epoch 3/50
# 71/71 [==============================] - 0s - loss: 0.8505 - acc: 0.5634
# Epoch 4/50
# 71/71 [==============================] - 0s - loss: 0.7578 - acc: 0.5211
# Epoch 5/50
# 71/71 [==============================] - 0s - loss: 0.8157 - acc: 0.5634
# Epoch 6/50
# 71/71 [==============================] - 0s - loss: 0.8335 - acc: 0.6056
# Epoch 7/50
# 71/71 [==============================] - 0s - loss: 0.9133 - acc: 0.5211
# Epoch 8/50
# 71/71 [==============================] - 0s - loss: 0.5865 - acc: 0.6901
# Epoch 9/50
# 71/71 [==============================] - 0s - loss: 0.5666 - acc: 0.7324
# Epoch 10/50
# 71/71 [==============================] - 0s - loss: 0.5757 - acc: 0.7606
# Epoch 11/50
# 71/71 [==============================] - 0s - loss: 0.6023 - acc: 0.6197
# Epoch 12/50
# 71/71 [==============================] - 0s - loss: 0.6345 - acc: 0.6479
# Epoch 13/50
# 71/71 [==============================] - 0s - loss: 0.6374 - acc: 0.7042
# Epoch 14/50
# 71/71 [==============================] - 0s - loss: 0.5907 - acc: 0.7042
# Epoch 15/50
# 71/71 [==============================] - 0s - loss: 0.5508 - acc: 0.7042
# Epoch 16/50
# 71/71 [==============================] - 0s - loss: 0.4418 - acc: 0.7746
# Epoch 17/50
# 71/71 [==============================] - 0s - loss: 0.6309 - acc: 0.6479
# Epoch 18/50
